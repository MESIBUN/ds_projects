# %% [markdown]
# <a href="https://colab.research.google.com/github/MESIBUN/ds_projects/blob/main/Copy_of_obesity_prediction_Auto_split.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, f1_score, recall_score
from tabulate import tabulate

# %%
df = pd.read_csv("obesity2.csv")    #Loading the dataset
df.head()
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# ...

# %%
df.shape #To see the number ofrows and columns
# Out:
# (2111, 17)

# %%
df.describe() #Statistical ata for numeric columns
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.312600     1.701677    86.586058     2.419043     2.685628
# std       6.345968     0.093305    26.191172     0.533927     0.778039
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.947192     1.630000    65.473343     2.000000     2.658738
# 50%      22.777890     1.700499    83.000000     2.385502     3.000000
# 75%      26.000000     1.768464   107.430682     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      2.008011     1.010298     0.657866
# std       0.612953     0.850592     0.608927
# min       1.000000     0.000000     0.000000
# 25%       1.584812     0.124505     0.000000
# 50%       2.000000     1.000000     0.625350
# ...

# %%
df.columns # says about the columns present in the data set
# Out:
# Index(['Gender', 'Age', 'Height', 'Weight', 'family_history_with_overweight',
#        'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE',
#        'CALC', 'MTRANS', 'NObeyesdad'],
#       dtype='object')

# %%
df.drop(columns ="TUE",inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   float64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2111 non-null   object
# ...

# %%
df.rename(columns={'NObeyesdad': 'Obesity_status'}, inplace=True) #renaming the column

# %%
df.rename(columns={'FAVC': 'FC_HCF'}, inplace=True) #FC_HCF - frequent consumption of high calories food

# %%
df.rename(columns={'FCVC': 'FC_Veg'}, inplace=True) # Frequency of consumption of vegetables

# %%
df.rename(columns={'NCP': 'No_MM'}, inplace=True)  #No.of main meals

# %%
df.rename(columns={'CAEC': 'CF_BM'}, inplace=True) #Consumption of food meals

# %%
df.rename(columns={'SCC': 'CCM'}, inplace=True) #Calories consumtion monitoring

# %%
df.rename(columns={'MTRANS': 'T_used'}, inplace=True) #Transportation used

# %%
df.isnull().sum() #checking null values
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FC_HCF                            0
# FC_Veg                            0
# No_MM                             0
# CF_BM                             0
# SMOKE                             0
# CH2O                              0
# CCM                               0
# FAF                               0
# CALC                              0
# T_used                            0
# Obesity_status                    0
# dtype: int64

# %%
# Data preprocessing

#Encoding categorical to numerical using LabelEncoding

from sklearn.preprocessing import LabelEncoder
columns_to_encode = ["Gender","family_history_with_overweight","FC_HCF","CF_BM","SMOKE","CCM","CALC","T_used"]
le = LabelEncoder()
df[columns_to_encode] = df[columns_to_encode].apply(lambda col: le.fit_transform(col))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   int64
#  1   Age                             2111 non-null   float64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   int64
#  5   FC_HCF                          2111 non-null   int64
#  6   FC_Veg                          2111 non-null   float64
#  7   No_MM                           2111 non-null   float64
#  8   CF_BM                           2111 non-null   int64
#  9   SMOKE                           2111 non-null   int64
#  10  CH2O                            2111 non-null   float64
#  11  CCM                             2111 non-null   int64
# ...

# %%
df.head()
# Out:
#    Gender   Age  Height  Weight  family_history_with_overweight  FC_HCF  \
# 0       0  21.0    1.62    64.0                               1       0
# 1       0  21.0    1.52    56.0                               1       0
# 2       1  23.0    1.80    77.0                               1       0
# 3       1  27.0    1.80    87.0                               0       0
# 4       1  22.0    1.78    89.8                               0       0
#
#    FC_Veg  No_MM  CF_BM  SMOKE  CH2O  CCM  FAF  CALC  T_used  \
# 0     2.0    3.0      2      0   2.0    0  0.0     3       3
# 1     3.0    3.0      2      1   3.0    1  3.0     2       3
# 2     2.0    3.0      2      0   2.0    0  2.0     1       3
# 3     3.0    3.0      2      0   2.0    0  2.0     1       4
# 4     2.0    1.0      2      0   2.0    0  0.0     2       3
#
#         Obesity_status
# 0        Normal_Weight
# 1        Normal_Weight
# 2        Normal_Weight
# 3   Overweight_Level_I
# 4  Overweight_Level_II

# %%
df["Obesity_status"]=le.fit_transform(df["Obesity_status"])

# %% [markdown]
# # Obesity status:
#
#
# 0- Insufficient Weight
#
# 1- Normal Weight
#
# 2- Overweight Level I
#
# 3- Overweight Level II
#
# 4- Obesity Type I
#
# 5- Obesity Type II
#
# 6- Obesity Type III

# %%
df["Obesity_status"].value_counts()
# Out:
# 2    351
# 4    324
# 3    297
# 5    290
# 6    290
# 1    287
# 0    272
# Name: Obesity_status, dtype: int64

# %%
X = df.drop(columns="Obesity_status")
X.shape
# Out:
# (2111, 15)

# %%
y = df["Obesity_status"]
y.shape
# Out:
# (2111,)

# %%
def performance(x_train, x_test, y_train, y_test, classifier):
    classifier.fit(x_train, y_train)
    y_pred = classifier.predict(x_test)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')
    f1 = f1_score(y_test, y_pred, average='weighted')
    return accuracy, precision, recall, f1

def find_optimal_split_ratio(x, y, classifiers, splitting_ratios):
    optimal_ratio = None
    max_accuracy = 0.0
    header = ["Test Ratio", "Classifier", "Accuracy", "Precision", "Recall", "F1-score"]
    table_data = []
    for test_ratio in splitting_ratios:
        x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=test_ratio, random_state=42)
        for classifier_name, classifier in classifiers.items():
            accuracy, precision, recall, f1 = performance(x_train, x_test, y_train, y_test, classifier)
            row_data = [f"{test_ratio:.2f}", classifier_name,
                        f"{accuracy:.4f}", f"{precision:.4f}",
                        f"{recall:.4f}", f"{f1:.4f}"]
            table_data.append(row_data)
            if accuracy > max_accuracy:
                max_accuracy = accuracy
                optimal_ratio = test_ratio
    print("\nOptimal Splitting Ratio:", optimal_ratio)
    print(tabulate(table_data, headers=header, tablefmt="grid"))

# %%
#define classifiers

classifiers= {'Random Forest': RandomForestClassifier(),
              'Logistic regression': LogisticRegression (),
              'Support Vector Machine': SVC(),
              'Decision Tree': DecisionTreeClassifier()
              }

# %%
#Define Splitting ratios to evaluate
splitting_ratios = np.linspace(0.1, 0.4)

# %%
import warnings
warnings.filterwarnings("ignore")

#Find the optimal splitting ratio
find_optimal_split_ratio(X, y, classifiers, splitting_ratios)
# Out:
# Optimal Splitting Ratio: 0.11224489795918369
# +--------------+------------------------+------------+-------------+----------+------------+
# |   Test Ratio | Classifier             |   Accuracy |   Precision |   Recall |   F1-score |
# +==============+========================+============+=============+==========+============+
# |         0.1  | Random Forest          |     0.9434 |      0.9428 |   0.9434 |     0.943  |
# +--------------+------------------------+------------+-------------+----------+------------+
# |         0.1  | Logistic regression    |     0.6651 |      0.6651 |   0.6651 |     0.6631 |
# +--------------+------------------------+------------+-------------+----------+------------+
# |         0.1  | Support Vector Machine |     0.5802 |      0.6334 |   0.5802 |     0.5663 |
# +--------------+------------------------+------------+-------------+----------+------------+
# |         0.1  | Decision Tree          |     0.9528 |      0.9546 |   0.9528 |     0.9532 |
# ...

# %%
# Building model
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

# %%
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
print("X_train :",X_train.shape)
print("X_test :",X_test.shape)
print("y_train :",y_train.shape)
print("y_test :",y_test.shape)
# Out:
# X_train : (1688, 15)
# X_test : (423, 15)
# y_train : (1688,)
# y_test : (423,)

# %%
# Standardizing  the features (optional but recommended for logistic regression)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Standardizing  the features (optional but recommended for logistic regression)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Creating a logistic regression model
model = LogisticRegression(random_state=6)
# Train the model
model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=6)

# %%
# Making predictions on the test set
predictions = model.predict(X_test)

# %%
 #Evaluating the model
from sklearn.metrics import accuracy_score, classification_report
accuracy = accuracy_score(y_test, predictions)
report = classification_report(y_test, predictions)

# %%
# Printing the results
print("Accuracy:", accuracy)
print("Classification Report:\n", report)
# Out:
# Accuracy: 0.9527186761229315
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93        65
#            1       0.87      0.70      0.78        57
#            2       0.95      0.94      0.95        67
#            3       0.98      1.00      0.99        53
#            4       0.96      1.00      0.98        69
#            5       0.78      0.86      0.82        57
#            6       0.90      0.82      0.86        55
#
#     accuracy                           0.91       423
#    macro avg       0.90      0.90      0.90       423
# weighted avg       0.91      0.91      0.90       423

# %%
# Decision tree
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from sklearn.tree import plot_tree


# Create a decision tree classifier
clf = DecisionTreeClassifier(criterion ="entropy",splitter="best",random_state =42)

# Fit the classifier to the training data
clf.fit(X_train, y_train)

# Make predictions on the test data
y_pred = clf.predict(X_test)

# Evaluate the accuracy of the model
accuracy = metrics.accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Accuracy: 0.95

# %%
# Support vector Machines(svm)
from sklearn.svm import SVC
# Creating an SVM classifier
svm_classifier = SVC(kernel='linear', C=1.0)

# Training the SVM classifier
svm_classifier.fit(X_train, y_train)

# Making predictions on the test set
y_pred = svm_classifier.predict(X_test)

# Evaluating the accuracy of the model

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 95.74%

# %%
y_pred = svm_classifier.predict([[0,23,1.66,68.0,1,0,2.0,2,1,1,2.0,	1,0.0,2,3]])
print(y_pred)
# Out:
# [4]

# %%
# Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
# Creating a Random Forest classifier
random_forest_classifier = RandomForestClassifier(n_estimators=100, random_state=42)

# Training the Random Forest classifier
random_forest_classifier.fit(X_train, y_train)

# Making predictions on the test set
y_pred = random_forest_classifier.predict(X_test)

# Evaluating the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 94.80%

# %%
X.head(1)
# Out:
#    Gender   Age  Height  Weight  family_history_with_overweight  FC_HCF  \
# 0       0  21.0    1.62    64.0                               1       0
#
#    FC_Veg  No_MM  CF_BM  SMOKE  CH2O  CCM  FAF  CALC  T_used
# 0     2.0    3.0      2      0   2.0    0  0.0     3       3
